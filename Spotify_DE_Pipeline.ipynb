# %%
pip install spotipy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from spotipy.oauth2 import SpotifyClientCredentials
import pandas as pd
import spotipy

# %% [markdown]
# * After we are done with importing the neccesaey libraries. We will move on to the Spotify api Part.

# %%
client_credentials_manager = SpotifyClientCredentials(client_id="5797537926c44ae7a89f60258adeca7c", client_secret="4eaea9d2b06f4c32b89d9daa61df020f")

# %%
sp = spotipy.Spotify(client_credentials_manager = client_credentials_manager)

# %%
playlist_link = "https://open.spotify.com/playlist/37i9dQZEVXbNG2KDcFcKOF?si=1333723a6eff4b7f"

# %%
playlist_URI = playlist_link.split('/')[-1].split('?')[0]

# %% [markdown]
# * Data Extractiona nd Data Cleaning

# %%
playlist_URI
# Out:
# '37i9dQZEVXbNG2KDcFcKOF'

# %%
data = sp.playlist_tracks(playlist_URI)

# %%
data
# Out:
# {'href': 'https://api.spotify.com/v1/playlists/37i9dQZEVXbNG2KDcFcKOF/tracks?offset=0&limit=100&additional_types=track',
#  'items': [{'added_at': '2024-10-18T12:31:37Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#     'href': 'https://api.spotify.com/v1/users/',
#     'id': '',
#     'type': 'user',
#     'uri': 'spotify:user:'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'preview_url': None,
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
# ...

# %%
data['items'][0]['track']['album']['id']
# Out:
# '10FLjwfpbxLmW8c25Xyc2N'

# %%
data['items'][0]['track']['album']['name']
# Out:
# 'Die With A Smile'

# %%
data['items'][0]['track']['album']['release_date']
# Out:
# '2024-08-16'

# %%
data['items'][0]['track']['album']['total_tracks']
# Out:
# 1

# %%
data['items'][0]['track']['album']['external_urls']['spotify']
# Out:
# 'https://open.spotify.com/album/10FLjwfpbxLmW8c25Xyc2N'

# %%
album_list = []
for row in data['items']:
    album_id = row['track']['album']['id']
    album_name = row['track']['album']['name']
    album_release_date = row['track']['album']['release_date']
    album_total_tracks = row['track']['album']['total_tracks']
    album_url = row['track']['album']['external_urls']['spotify']
    album_element = {'album_id':album_id,'name':album_name,'release_date':album_release_date,
                        'total_tracks':album_total_tracks,'url':album_url}
    album_list.append(album_element)

# %%
album_list
# Out:
# [{'album_id': '10FLjwfpbxLmW8c25Xyc2N',
#   'name': 'Die With A Smile',
#   'release_date': '2024-08-16',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/10FLjwfpbxLmW8c25Xyc2N'},
#  {'album_id': '7aJuG4TFXa2hmE4z1yxc3n',
#   'name': 'HIT ME HARD AND SOFT',
#   'release_date': '2024-05-17',
#   'total_tracks': 10,
#   'url': 'https://open.spotify.com/album/7aJuG4TFXa2hmE4z1yxc3n'},
#  {'album_id': '15XcLhiVMlSOipUddTNDnr',
#   'name': 'MUSE',
#   'release_date': '2024-07-19',
#   'total_tracks': 7,
#   'url': 'https://open.spotify.com/album/15XcLhiVMlSOipUddTNDnr'},
#  {'album_id': '3iPSVi54hsacKKl1xIR2eH',
#   'name': "Short n' Sweet",
#   'release_date': '2024-08-23',
#   'total_tracks': 12,
#   'url': 'https://open.spotify.com/album/3iPSVi54hsacKKl1xIR2eH'},
#  {'album_id': '3iPSVi54hsacKKl1xIR2eH',
#   'name': "Short n' Sweet",
#   'release_date': '2024-08-23',
#   'total_tracks': 12,
#   'url': 'https://open.spotify.com/album/3iPSVi54hsacKKl1xIR2eH'},
# ...

# %%
data['items'][0]['track']['artists']
# Out:
# [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'},
#   'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms',
#   'id': '1HY2Jd0NmPuamShAr6KMms',
#   'name': 'Lady Gaga',
#   'type': 'artist',
#   'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/0du5cEVh5yTK9QJze8zA0C'},
#   'href': 'https://api.spotify.com/v1/artists/0du5cEVh5yTK9QJze8zA0C',
#   'id': '0du5cEVh5yTK9QJze8zA0C',
#   'name': 'Bruno Mars',
#   'type': 'artist',
#   'uri': 'spotify:artist:0du5cEVh5yTK9QJze8zA0C'}]

# %%
artist_list = []
for row in data['items']:
    for key, value in row.items():
        if key == "track":
            for artist in value['artists']:
                artist_dict = {'artist_id':artist['id'], 'artist_name':artist['name'], 'external_url': artist['href']}
                artist_list.append(artist_dict)

# %%
artist_list
# Out:
# [{'artist_id': '1HY2Jd0NmPuamShAr6KMms',
#   'artist_name': 'Lady Gaga',
#   'external_url': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms'},
#  {'artist_id': '0du5cEVh5yTK9QJze8zA0C',
#   'artist_name': 'Bruno Mars',
#   'external_url': 'https://api.spotify.com/v1/artists/0du5cEVh5yTK9QJze8zA0C'},
#  {'artist_id': '6qqNVTkY8uBg9cP3Jd7DAH',
#   'artist_name': 'Billie Eilish',
#   'external_url': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH'},
#  {'artist_id': '1oSPZhvZMIrWW5I41kPkkY',
#   'artist_name': 'Jimin',
#   'external_url': 'https://api.spotify.com/v1/artists/1oSPZhvZMIrWW5I41kPkkY'},
#  {'artist_id': '74KM79TiuVKeVCqs8QtB0B',
#   'artist_name': 'Sabrina Carpenter',
#   'external_url': 'https://api.spotify.com/v1/artists/74KM79TiuVKeVCqs8QtB0B'},
#  {'artist_id': '74KM79TiuVKeVCqs8QtB0B',
#   'artist_name': 'Sabrina Carpenter',
#   'external_url': 'https://api.spotify.com/v1/artists/74KM79TiuVKeVCqs8QtB0B'},
# ...

# %%
song_list = []
for row in data['items']:
    song_id = row['track']['id']
    song_name = row['track']['name']
    song_duration = row['track']['duration_ms']
    song_url = row['track']['external_urls']['spotify']
    song_popularity = row['track']['popularity']
    song_added = row['added_at']
    album_id = row['track']['album']['id']
    artist_id = row['track']['album']['artists'][0]['id']
    song_element = {'song_id':song_id,'song_name':song_name,'duration_ms':song_duration,'url':song_url,
                    'popularity':song_popularity,'song_added':song_added,'album_id':album_id,
                    'artist_id':artist_id
                   }
    song_list.append(song_element)

# %%
song_list
# Out:
# [{'song_id': '2plbrEY59IikOBgBGLjaoe',
#   'song_name': 'Die With A Smile',
#   'duration_ms': 251667,
#   'url': 'https://open.spotify.com/track/2plbrEY59IikOBgBGLjaoe',
#   'popularity': 100,
#   'song_added': '2024-10-18T12:31:37Z',
#   'album_id': '10FLjwfpbxLmW8c25Xyc2N',
#   'artist_id': '1HY2Jd0NmPuamShAr6KMms'},
#  {'song_id': '6dOtVTDdiauQNBQEDOtlAB',
#   'song_name': 'BIRDS OF A FEATHER',
#   'duration_ms': 210373,
#   'url': 'https://open.spotify.com/track/6dOtVTDdiauQNBQEDOtlAB',
#   'popularity': 98,
#   'song_added': '2024-10-18T12:31:37Z',
#   'album_id': '7aJuG4TFXa2hmE4z1yxc3n',
#   'artist_id': '6qqNVTkY8uBg9cP3Jd7DAH'},
#  {'song_id': '7tI8dRuH2Yc6RuoTjxo4dU',
#   'song_name': 'Who',
#   'duration_ms': 170887,
#   'url': 'https://open.spotify.com/track/7tI8dRuH2Yc6RuoTjxo4dU',
#   'popularity': 92,
#   'song_added': '2024-10-18T12:31:37Z',
#   'album_id': '15XcLhiVMlSOipUddTNDnr',
#   'artist_id': '1oSPZhvZMIrWW5I41kPkkY'},
#  {'song_id': '5G2f63n7IPVPPjfNIGih7Q',
# ...

# %%
album_df = pd.DataFrame.from_dict(album_list)
album_df
# Out:
#                   album_id                                               name  \
# 0   10FLjwfpbxLmW8c25Xyc2N                                   Die With A Smile
# 1   7aJuG4TFXa2hmE4z1yxc3n                               HIT ME HARD AND SOFT
# 2   15XcLhiVMlSOipUddTNDnr                                               MUSE
# 3   3iPSVi54hsacKKl1xIR2eH                                     Short n' Sweet
# 4   3iPSVi54hsacKKl1xIR2eH                                     Short n' Sweet
# 5   1WAjjRMfZjEXtB0lQrAw6Q                                   Good Luck, Babe!
# 6   5ylbxH7EqpsmHZCRuiYewS                       Si Antes Te Hubiera Conocido
# 7   2IRxVVqbSbqHJo8Zx50LYn                                           Timeless
# 8   68CN2LzY8MoxO2udy2C22e                                        Sailor Song
# 9   3iPSVi54hsacKKl1xIR2eH                                     Short n' Sweet
# 10  3e5tDT1kfaAGx10yOjIDgW                                             Mantra
# ...

# %%
album_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   album_id      50 non-null     object
#  1   name          50 non-null     object
#  2   release_date  50 non-null     object
#  3   total_tracks  50 non-null     int64
#  4   url           50 non-null     object
# dtypes: int64(1), object(4)
# memory usage: 2.1+ KB

# %%
album_df = album_df.drop_duplicates(subset=['album_id'])

# %%
artist_df = pd.DataFrame.from_dict(artist_list)
artist_df
# Out:
#                  artist_id         artist_name  \
# 0   1HY2Jd0NmPuamShAr6KMms           Lady Gaga
# 1   0du5cEVh5yTK9QJze8zA0C          Bruno Mars
# 2   6qqNVTkY8uBg9cP3Jd7DAH       Billie Eilish
# 3   1oSPZhvZMIrWW5I41kPkkY               Jimin
# 4   74KM79TiuVKeVCqs8QtB0B   Sabrina Carpenter
# ..                     ...                 ...
# 63  4V8LLVI7PbaPR0K2TGSxFF  Tyler, The Creator
# 64  1U1el3k54VvEUzo3ybLPlM          Kali Uchis
# 65  2YZyLoL8N0Wb9xBt1NhZWg      Kendrick Lamar
# 66  25uiPmTg16RbhZWAqwLBy5          Charli xcx
# 67  66CXWjxzNUsdJxJ2JdwvnR       Ariana Grande
#
#                                          external_url
# 0   https://api.spotify.com/v1/artists/1HY2Jd0NmPu...
# 1   https://api.spotify.com/v1/artists/0du5cEVh5yT...
# 2   https://api.spotify.com/v1/artists/6qqNVTkY8uB...
# 3   https://api.spotify.com/v1/artists/1oSPZhvZMIr...
# 4   https://api.spotify.com/v1/artists/74KM79TiuVK...
# ..                                                ...
# ...

# %%
artist_df = artist_df.drop_duplicates(subset=['artist_id'])

# %%
song_df = pd.DataFrame.from_dict(song_list)
song_df
# Out:
#                    song_id                                       song_name  \
# 0   2plbrEY59IikOBgBGLjaoe                                Die With A Smile
# 1   6dOtVTDdiauQNBQEDOtlAB                              BIRDS OF A FEATHER
# 2   7tI8dRuH2Yc6RuoTjxo4dU                                             Who
# 3   5G2f63n7IPVPPjfNIGih7Q                                           Taste
# 4   2HRqTpkrJO5ggZyyK6NPWz                                        Espresso
# 5   0WbMK4wrZ1wFSty9F7FCgu                                Good Luck, Babe!
# 6   6WatFBLVB0x077xWeoVc2k                    Si Antes Te Hubiera Conocido
# 7   1Es7AUAhQvapIcoh3qMKDL                   Timeless (with Playboi Carti)
# 8   2262bWmqomIaJXwCRHr13j                                     Sailor Song
# 9   2tHwzyyOLoWSFqYNjeVMzj                            Please Please Please
# 10  2CspwnypzT7rcWI9RfsoSb                                          Mantra
# ...

# %%
album_df['release_date'] = pd.to_datetime(album_df['release_date'])
# Out:
# /var/folders/q9/x3v31xns0jqfmcdmgv_3tztr0000gn/T/ipykernel_53465/3126744046.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   album_df['release_date'] = pd.to_datetime(album_df['release_date'])

# %%
album_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 42 entries, 0 to 48
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   album_id      42 non-null     object
#  1   name          42 non-null     object
#  2   release_date  42 non-null     datetime64[ns]
#  3   total_tracks  42 non-null     int64
#  4   url           42 non-null     object
# dtypes: datetime64[ns](1), int64(1), object(3)
# memory usage: 2.0+ KB

# %%
song_df['song_added'] =  pd.to_datetime(song_df['song_added'])

# %%
song_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   song_id      50 non-null     object
#  1   song_name    50 non-null     object
#  2   duration_ms  50 non-null     int64
#  3   url          50 non-null     object
#  4   popularity   50 non-null     int64
#  5   song_added   50 non-null     datetime64[ns, UTC]
#  6   album_id     50 non-null     object
#  7   artist_id    50 non-null     object
# dtypes: datetime64[ns, UTC](1), int64(2), object(5)
# memory usage: 3.3+ KB
